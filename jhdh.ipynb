# %%
import nbformat

nb = nbformat.read("Customer_Credit_Risk_Data_Preprocessing.ipynb", as_version=4)

if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]

nbformat.write(nb, "fixed_notebook.ipynb")
